# %% [markdown]
# <a href="https://colab.research.google.com/github/KrivonosoffGS/letsgoo/blob/hometask_2/hometask2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# **1. Создайте двумерный массив 10x3, заполненный случайными значениями. В каждой строке выберите значение, наиболее близкое к 0.5.**

# %%
a = np.random.random((10, 3))
print(a)
for x in range (10):
  b = np.abs(a[x] - 0.5).min()
  print(b + 0.5)
# Out:
# [[0.53223311 0.40890117 0.52005174]
#  [0.63736842 0.89098388 0.05040061]
#  [0.56827106 0.24908724 0.18681581]
#  [0.89529256 0.14174737 0.46332365]
#  [0.76104512 0.76940905 0.54792696]
#  [0.73329945 0.96796914 0.38256894]
#  [0.60218924 0.95560616 0.91655769]
#  [0.13249062 0.54284042 0.95691831]
#  [0.90367716 0.49590183 0.64113157]
#  [0.53396733 0.22892718 0.46642517]]
# 0.5200517368780275
# 0.6373684224187252
# 0.5682710601558929
# 0.5366763528859666
# 0.5479269624872773
# 0.6174310597411113
# 0.6021892395002022
# 0.5428404217623063
# 0.5040981700258158
# 0.533574827447051

# %% [markdown]
# **2. Создайте двумерный массив 6x6, заполненный случайными значениями. Затем сумму по каждой строке поделите на минимальный элемент из столбца с тем же индексом.**

# %%
c = np.random.random((6, 6))
print(c)
for x in range (6):
  d = c[:,x]
  print('===========================')
  print('column = ', d)
  f = np.sum(c[x])
  print('sum =',  f)
  e = np.min(c[:,x])
  print('min =',  e)
  print('sum/min =',  f/e)
# Out:
# [[0.10960622 0.64886102 0.87187947 0.66113402 0.34222401 0.54684638]
#  [0.97461477 0.77506279 0.01475274 0.19867674 0.31118621 0.49953766]
#  [0.80685497 0.47858335 0.09383271 0.20445221 0.84673409 0.6993991 ]
#  [0.61869231 0.73857047 0.61517392 0.49219735 0.99025067 0.70210463]
#  [0.65291301 0.14609885 0.56102283 0.65437623 0.74528696 0.56549169]
#  [0.85898706 0.51613076 0.48224277 0.80679382 0.03448992 0.19284386]]
# ...
# column =  [0.10960622 0.97461477 0.80685497 0.61869231 0.65291301 0.85898706]
# sum = 3.180551121235075
# min = 0.10960621691477612
# sum/min = 29.017981012045148
# ...
# column =  [0.64886102 0.77506279 0.47858335 0.73857047 0.14609885 0.51613076]
# sum = 2.773830906032424
# min = 0.14609884860461186
# sum/min = 18.985987449766
# ...
# column =  [0.87187947 0.01475274 0.09383271 0.61517392 0.56102283 0.48224277]
# sum = 3.12985642149087
# min = 0.014752739523921865
# sum/min = 212.15425219266865
# ...
# column =  [0.66113402 0.19867674 0.20445221 0.49219735 0.65437623 0.80679382]
# ...

# %% [markdown]
# **3. На примере массива x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) найдите максимальный элемент в массиве среди элементов, перед которыми стоит ноль.**

# %%
x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0])
g = []
for i in range (1, x.size):
  if x[i-1] == 0:
    g.append(x[i])
print(np.max(g))
# Out:
# 5

# %% [markdown]
# **4. Пусть заданы два массива x = np.ones(10) и i = np.array([0, 1, 2, 3, 5, 5, 5, 8]). Прибавьте единицу к тем элементам массива x, индексы которых указаны в массиве i. В случае, если некоторый индекс встретился в массиве i несколько раз, прибавьте к соответствующему элементу массива x число вхождений данного индекса в массив i.**

# %%
x = np.ones(10)
i = np.array([0, 1, 2, 3, 5, 5, 5, 8])
#x[i] = x[i] + 1
#print(x)
for z in i:
  x[z]+=1
print(x)
# Out:
# [2. 2. 2. 2. 1. 4. 1. 1. 2. 1.]

# %% [markdown]
# **5. Написать функцию, реализующую алгоритм k-means. Входные и выходные значения функции должны быть аналогичны https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.cluster.vq.kmeans.html. Функция должна содержать не более двух циклов while (for).**

# %%
url = 'https://raw.githubusercontent.com/sharmaroshan/Clustering-of-Mall-Customers/master/Mall_Customers.csv'
data = np.loadtxt(url, delimiter=',', dtype=object, skiprows=1)
data[:5]
# Out:
# array([['0001', 'Male', '19', '15', '39'],
#        ['0002', 'Male', '21', '15', '81'],
#        ['0003', 'Female', '20', '16', '6'],
#        ['0004', 'Female', '23', '16', '77'],
#        ['0005', 'Female', '31', '17', '40']], dtype=object)

# %%
data[:, 1] = data[:, 1] == 'Male'
data = data.astype(float)
data[:5]
# Out:
# array([[ 1.,  1., 19., 15., 39.],
#        [ 2.,  1., 21., 15., 81.],
#        [ 3.,  0., 20., 16.,  6.],
#        [ 4.,  0., 23., 16., 77.],
#        [ 5.,  0., 31., 17., 40.]])

# %%
import matplotlib.pyplot as plt

plt.scatter(data[:, 2], data[:, 3])
plt.xlabel('Age')
plt.ylabel('Annual Income')
plt.show()

# %%
plt.scatter(data[:, 2], data[:, 4])
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.show()

# %%
plt.scatter(data[:, 3], data[:, 4])
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

# %%
def norming (data):
  mean = data.mean(axis=0)
  std = data.std(axis=0)
  return (data - mean)/std

# %%
import numpy.random 
from scipy.spatial import distance
def kmeans(obs, k_or_guess, iter=20, thresh=1e-05): #k_or_guess has int or ndarray type
  if type(k_or_guess) == int:
    arr = obs[np.random.choice(range(len(obs)), k_or_guess, False)]
  else:
    arr = k_or_guess
  prev_dist = -1
  cur_dist = distance.cdist(obs, arr, 'sqeuclidean').min(axis = 1).sum()
    
  while abs(cur_dist - prev_dist) > thresh:
    new_arr = np.empty((len(arr),len(arr[0])))
    dist = distance.cdist(obs, arr, 'sqeuclidean')
    temp = np.hstack((obs, dist.argmin(axis=1).reshape(len(dist),1)))
    for i in range(len(arr)):
      new_arr[i] = temp[temp[:, -1] == i].mean(axis=0)[:-1]
    arr = new_arr
    prev_dist = cur_dist
    cur_dist = distance.cdist(obs, arr, 'sqeuclidean').min(axis = 1).sum()    
  return arr, cur_dist

# %% [markdown]
# **6. С помощью реализованной функции kmeans выделить кластеры клиентов в разрезах возраст-доход, возрвст-покупательский индекс, доход-покупательский индекс. В каждом случае использовать elbow method для определения оптимального числа кластеров. Визуализировать полученные кластеры (каждый кластер изобразить собственным цветом). Дать интерпретацию полученным кластерам.**

# %% [markdown]
# разрез: возраст - доход

# %%
norm = norming (data[:,2:])
dist_k = np.empty(9)             
for i in range(1,10):
  codebook, distor = kmeans(norm[:,[0,1]], i)
  dist_k[i-1] = distor
plt.plot(range(1,10), dist_k, label = "Elbow method")
plt.legend()
plt.grid(True)

# %% [markdown]
# полагаем k=3

# %%
codebook, distor = kmeans(norm[:,[0,1]], 3)
distortion = distance.cdist(norm[:,[0,1]], codebook, 'sqeuclidean')
matrix = np.hstack((norm[:,[0,1]], distortion.argmin(axis=1).reshape(len(distortion),1)))
part1 = matrix[matrix[:, -1] == 0]
part2 = matrix[matrix[:, -1] == 1]
part3 = matrix[matrix[:, -1] == 2]

plt.scatter(part1[:,0], part1[:,1], c='g', label='First group')
plt.scatter(part2[:,0], part2[:,1], c='r', label='Second group')
plt.scatter(part3[:,0], part3[:,1], c='b', label='Third group')
plt.axis('equal')
plt.xlabel("Age")
plt.ylabel('Annual Income')
plt.legend()
plt.show()

# %% [markdown]
# Доход среднего класса в 1 кластере выше дохода 2 и 3, где молодые и, наоборот, пожилые.

# %% [markdown]
# разрез: возраст - покупательский индекс

# %%
dist_k = np.empty(9)
for i in range(1,10):
    codebook, distor = kmeans(norm[:,[0,2]], i)
    dist_k[i-1] = distor
plt.plot(range(1,10), dist_k, label = "Elbow method")
plt.legend()
plt.grid(True)

# %% [markdown]
# за локоть тут примем k=4

# %%
codebook, distor = kmeans(norm[:,[0,2]], 4)     # Найдя оптимальное k, разделяем на k кластеров(тут k=4)

distortion = distance.cdist(norm[:,[0,2]], codebook, 'sqeuclidean')
matrix = np.hstack((norm[:,[0,2]], distortion.argmin(axis=1).reshape(len(distortion),1)))
part1 = matrix[matrix[:, -1] == 0]
part2 = matrix[matrix[:, -1] == 1]
part3 = matrix[matrix[:, -1] == 2]
part4 = matrix[matrix[:, -1] == 3]


plt.scatter(part1[:,0], part1[:,1], c='g', label='First group')
plt.scatter(part2[:,0], part2[:,1], c='c', label='Second group')
plt.scatter(part3[:,0], part3[:,1], c='b', label='Third group')
plt.scatter(part4[:,0], part4[:,1], c='r', label='Fourth group')

plt.axis('equal')
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.legend()
plt.show()

# %% [markdown]
# Наибольший покупательский индекс у молодых во 2 кластере. Наименьщий - у людей среднего возраста в 4 кластере.

# %% [markdown]
# разрез: доход - покупательский индекс

# %%
dist_k = np.empty(9)                       # Elbow-метод для категорий годовой доход-затраты
for i in range(1,10):
  codebook, distor = kmeans(norm[:,[1,2]], i)
  dist_k[i-1] = distor
plt.plot(range(1,10), dist_k, label = "Elbow method")
plt.legend()
plt.grid(True)

# %% [markdown]
# k=5

# %%
codebook, distor = kmeans(norm[:,[1,2]], 5)

distortion = distance.cdist(norm[:,[1,2]], codebook, 'sqeuclidean')
matrix = np.hstack((norm[:,[1,2]], distortion.argmin(axis=1).reshape(len(distortion),1)))
part1 = matrix[matrix[:, -1] == 0]
part2 = matrix[matrix[:, -1] == 1]
part3 = matrix[matrix[:, -1] == 2]
part4 = matrix[matrix[:, -1] == 3]
part5 = matrix[matrix[:, -1] == 4]


plt.scatter(part1[:,0], part1[:,1], c='g', label='First group')
plt.scatter(part2[:,0], part2[:,1], c='c', label='Second group')
plt.scatter(part3[:,0], part3[:,1], c='b', label='Third group')
plt.scatter(part4[:,0], part4[:,1], c='r', label='Fourth group')
plt.scatter(part5[:,0], part5[:,1], c='m', label='Fifth group')


plt.axis('equal')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.legend()
plt.show()

# %% [markdown]
# Видно четкое разделение на четверти.
